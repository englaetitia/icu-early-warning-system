# %% [markdown]
# # Week 3 Day 6 — SHAP Dashboard Integration
#
# ## ICU Early Warning Prediction System
#
# The objective of this stage is to integrate SHAP explainability outputs into the Streamlit dashboard.
#
# This allows the dashboard to answer not only:
#
# > Who is at risk?
#
# but also:
#
# > Why did the model make this prediction?
#
# This is an important step toward explainable clinical decision support.

# %%
from pathlib import Path

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %%
PROJECT_ROOT = Path.cwd().parent

SHAP_FIGURES_DIR = PROJECT_ROOT / "figures" / "day8"

print("SHAP figures directory:", SHAP_FIGURES_DIR)
print("Directory exists:", SHAP_FIGURES_DIR.exists())

for file in SHAP_FIGURES_DIR.iterdir():
    print(file.name)
# Out:
# SHAP figures directory: c:\Users\User\OneDrive\Desktop\icu-early-warning-system\figures\day8
# Directory exists: True
# patient_level_shap_waterfall.png
# shap_bar_plot.png
# shap_summary_plot.png

# %% [markdown]
# ## SHAP Figures Used
#
# The dashboard will use previously generated SHAP explainability outputs:
#
# - SHAP Summary Plot
# - SHAP Bar Plot
# - Patient-Level SHAP Waterfall Plot
#
# These figures allow clinicians and users to understand both global model behavior and individual prediction explanations.
