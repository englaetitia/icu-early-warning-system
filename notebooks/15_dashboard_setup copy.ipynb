# %% [markdown]
# # Week 3 Day 1 — Streamlit Dashboard Setup
#
# ## ICU Early Warning Prediction System
#
# Week 3 focuses on transforming the ICU Early Warning Prediction System from research notebooks into an interactive healthcare dashboard.
#
# The goal of Day 1 is to create the first working Streamlit application.
#
# This dashboard will later support:
#
# - patient monitoring
# - sepsis risk visualization
# - clinical alert levels
# - patient search
# - explainable AI using SHAP

# %% [markdown]
# ## 1. Dashboard Development Goal
#
# The objective of this notebook is to prepare the initial Streamlit dashboard structure.
#
# Today we will create:
#
# - dashboard configuration file
# - reusable utility file
# - main Streamlit application file
# - sidebar navigation
# - dashboard homepage

# %%
# !pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Ignoring invalid distribution ~angchain-core (C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-core (C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-core (C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# ...

# %% [markdown]
# ## 2. App Folder Structure
#
# The Streamlit application is stored inside the `app/` folder.
#
# The main files are:
#
# ```text
# app/
# ├── config.py
# ├── utils.py
# └── streamlit_app.py
